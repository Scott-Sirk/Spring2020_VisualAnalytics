# %% [markdown]
# # Load DataFrames

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

path_root = "/Spring2020_VisualAnalytics/output/"

df_academies = pd.read_csv(os.path.join(path_root, "academies.tsv"), index_col="SP ID", sep='\t', encoding = "unicode_escape")
df_aristo_title = pd.read_csv(os.path.join(path_root, "aristo_title.tsv"), index_col="SP ID", sep='\t', encoding = "unicode_escape")
df_egonetworkscombined = pd.read_csv(os.path.join(path_root, "egonetworkscombined.tsv"), index_col="SP ID", sep='\t', encoding = "unicode_escape")
df_knowledge_network = pd.read_csv(os.path.join(path_root, "knowledge_network.tsv"), index_col="SP ID", sep='\t', encoding = "unicode_escape")
df_main = pd.read_csv(os.path.join(path_root, "main.tsv"), index_col="SP ID", sep='\t', encoding = "unicode_escape")
df_military_rank = pd.read_csv(os.path.join(path_root, "military_rank.tsv"), index_col="SP ID", sep='\t', encoding = "unicode_escape")
df_nationality = pd.read_csv(os.path.join(path_root, "nationality.tsv"), index_col="SP ID", sep='\t', encoding = "unicode_escape")
df_occupation = pd.read_csv(os.path.join(path_root, "occupation.tsv"), index_col="SP ID", sep='\t', encoding = "unicode_escape")
df_political_rank = pd.read_csv(os.path.join(path_root, "political_rank.tsv"), index_col="SP ID", sep='\t', encoding = "unicode_escape")
df_professional_network = pd.read_csv(os.path.join(path_root, "professional_network.tsv"), index_col="SP ID", sep='\t', encoding = "unicode_escape")
df_salons = pd.read_csv(os.path.join(path_root, "salons.tsv"), index_col="SP ID", sep='\t', encoding = "unicode_escape")
df_social_network = pd.read_csv(os.path.join(path_root, "social_network.tsv"), index_col="SP ID", sep='\t', encoding = "unicode_escape")
df_source = pd.read_csv(os.path.join(path_root, "source.tsv"), index_col="SP ID", sep='\t', encoding = "unicode_escape")

# %% [markdown]
# # Review DataFrames & Basic Visualizations

# %%
def category_prob_barh(df, column, other_threshold=0.02):
    # set figure size and facecolor
    plt.rcParams["figure.figsize"] = (20,12)
    plt.rcParams['axes.facecolor'] = 'ffffff'
    plt.rcParams["figure.facecolor"] = 'ffffff'
    
    prob = df[column].value_counts(normalize=True)
    threshold = other_threshold
    mask = prob > threshold
    tail_prob = prob.loc[~mask].sum()
    prob = prob.loc[mask]
    prob['other'] = tail_prob
    prob[::-1].plot(kind='barh')
    plt.xticks(rotation=0, size=20)
    plt.yticks(size=20)

    plt.show()
    
def category_count_barh(df, column, top_n):
    df[column].value_counts()[:top_n].plot(kind='barh', fontsize=20).invert_yaxis()

# %% [markdown]
# ## Main

# %%
df_main.info()
display(df_main.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 782 entries, 1000 to 1781
# Data columns (total 41 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Wikipedia URL                  412 non-null    object
#  1   EE ID                          201 non-null    object
#  2   Full Name                      782 non-null    object
#  3   Full Name Reversed             684 non-null    object
#  4   Particule?                     312 non-null    object
#  5   Relationships                  3 non-null      object
#  6   Clerical title                 40 non-null     object
#  7   Religious Network              85 non-null     object
#  8   Royal Academy                  83 non-null     object
#  9   Institut de France             19 non-null     object
#  10  Academy_single                 49 non-null     object
#  11  Academiy_single_provincial     10 non-null     object
#  12  Encyclopedistes                145 non-null    object
#  13  Freemason                      12 non-null     object
#  14  Jacobin                        9 non-null      object
#  15  Socit des Trente             1 non-null      object
#  16  Lodge                          4 non-null      object
#  17  GenderGroup                    779 non-null    object
#  18  Birth Date                     404 non-null    object
#  19  Birth Year                     504 non-null    object
#  20  Death Date                     403 non-null    object
#  21  Death Year                     499 non-null    object
#  22  Birth City                     388 non-null    object
#  23  Birth Country                  432 non-null    object
#  24  Death City                     362 non-null    object
#  25  Death Country                  413 non-null    object
#  26  LockeNet                       187 non-null    object
#  27  ASmithNet                      188 non-null    object
#  28  VoltaireNet                    194 non-null    object
#  29  RousseauNet                    190 non-null    object
#  30  D'AlembertNet                  191 non-null    object
#  31  HumeNet                        189 non-null    object
#  32  BenthamNet                     186 non-null    object
#  33  Column6                        0 non-null      float64
#  34  Wikipedia Image Link           148 non-null    object
#  35  VIAF ID                        329 non-null    object
#  36  VIAF URL                       320 non-null    object
#  37  RecipientLetterCount by EE ID  200 non-null    float64
#  38  AuthorLetterCount by EE ID     200 non-null    float64
#  39  Total Letters                  200 non-null    float64
#  40  CNRS-D ID                      61 non-null     object
# dtypes: float64(4), object(37)
# memory usage: 256.6+ KB
#                                            Wikipedia URL             EE ID  \
# SP ID
# 1000    http://en.wikipedia.org/wiki/Pierre_Beaumarchais  caronpierr000543
# 1001    http://en.wikipedia.org/wiki/Claude_Joseph_Dorat  doratclaud001336
# 1002   http://en.wikipedia.org/wiki/Claude-Carloman_d...  rulhiclaud001189
# 1003   http://en.wikipedia.org/wiki/Simon-Nicholas_He...  lingusimon002350
# 1004   http://en.wikipedia.org/wiki/Jean-Jacques_Rous...  roussjeanj003042
# 1005   http://en.wikipedia.org/wiki/Louis_Petit_de_Ba...  petitlouis001155
# 1006   http://en.wikipedia.org/wiki/Christoph_Williba...  gluckchris024379
# 1007   http://en.wikipedia.org/wiki/Henri_Franois_d'...  daguehenri000832
# 1008   http://en.wikipedia.org/wiki/Marie_Anne_de_Bou...               NaN
# 1009   http://en.wikipedia.org/wiki/index.html?curid=...               NaN
#
#                                    Full Name  \
# SP ID
# 1000   Pierre Augustin Caron de Beaumarchais
# 1001                     Claude Joseph Dorat
# 1002             Claude Carloman de Rulhire
# 1003             Simon Nicolas Henri Linguet
# 1004                   Jean-Jacques Rousseau
# 1005               Louis Petit de Bachaumont
# 1006           Christoph Willibald von Gluck
# 1007              Henri Franois D'Aguesseau
# 1008                   Marie Anne de Bourbon
# 1009                     Johann Samuel Knig
#
#                            Full Name Reversed Particule? Relationships  \
# SP ID
# 1000   Caron de Beaumarchais, Pierre Augustin        Yes           NaN
# 1001                     Dorat, Claude Joseph        NaN           NaN
# 1002             Rulhire, Claude Carloman de        Yes           NaN
# 1003             Linguet, Simon Nicolas Henri        NaN           NaN
# 1004                   Rousseau, Jean Jacques        NaN           NaN
# 1005               Petit de Bachaumont, Louis        Yes           NaN
# 1006           Gluck, Christoph Willibald von        NaN           NaN
# 1007              D'Aguesseau, Henri Franois        NaN           NaN
# 1008                   Bourbon, Marie Anne de        Yes           NaN
# 1009                    Knig, Johann Samuel         NaN           NaN
#
#       Clerical title Religious Network Royal Academy Institut de France  ...  \
# SP ID                                                                    ...
# 1000             NaN               NaN           NaN                NaN  ...
# 1001             NaN               NaN           NaN                NaN  ...
# 1002             NaN               NaN           Yes                NaN  ...
# 1003             NaN               NaN           NaN                NaN  ...
# 1004             NaN               NaN           NaN                NaN  ...
# 1005             NaN               NaN           NaN                NaN  ...
# 1006             NaN               NaN           NaN                NaN  ...
# 1007             NaN               NaN           Yes                NaN  ...
# 1008             NaN               NaN           NaN                NaN  ...
# 1009             NaN               NaN           Yes                NaN  ...
#
#       HumeNet BenthamNet Column6  \
# SP ID
# 1000                         NaN
# 1001                         NaN
# 1002                         NaN
# 1003                         NaN
# 1004     Hume                NaN
# 1005                         NaN
# 1006                         NaN
# 1007                         NaN
# 1008      NaN        NaN     NaN
# 1009      NaN        NaN     NaN
#
#                                     Wikipedia Image Link    VIAF ID  \
# SP ID
# 1000   upload.wikimedia.org/wikipedia/commons/thumb/a...   29529962
# 1001   upload.wikimedia.org/wikipedia/commons/thumb/4...   46760144
# 1002                                                 NaN   59160459
# 1003   upload.wikimedia.org/wikipedia/commons/thumb/2...    7393445
# 1004   upload.wikimedia.org/wikipedia/commons/thumb/b...  100184045
# 1005   upload.wikimedia.org/wikipedia/commons/thumb/0...   29558790
# 1006   upload.wikimedia.org/wikipedia/commons/thumb/8...   37101876
# 1007   http://upload.wikimedia.org/wikipedia/commons/...   73848894
# 1008                                                 NaN        NaN
# 1009                                                 NaN   66494565
#
#                               VIAF URL RecipientLetterCount by EE ID  \
# SP ID
# 1000          http://viaf.org/29529962                           0.0
# 1001          http://viaf.org/46760144                           8.0
# 1002          http://viaf.org/59160459                           2.0
# 1003           http://viaf.org/7393445                           4.0
# 1004         http://viaf.org/100184045                        2455.0
# 1005          http://viaf.org/29558790                           1.0
# 1006          http://viaf.org/37101876                           0.0
# 1007          http://viaf.org/73848894                           2.0
# 1008                               NaN                           NaN
# 1009   https://viaf.org/viaf/66494565/                           NaN
#
#       AuthorLetterCount by EE ID Total Letters       CNRS-D ID
# SP ID
# 1000                         0.0           0.0             NaN
# 1001                         4.0          12.0             NaN
# 1002                         3.0           5.0             NaN
# 1003                         4.0           8.0         Linguet
# 1004                      2284.0        4739.0  Rousseau J.-J.
# 1005                         0.0           1.0             NaN
# 1006                         0.0           0.0             NaN
# 1007                         4.0           6.0             NaN
# 1008                         NaN           NaN             NaN
# 1009                         NaN           NaN             NaN
#
# [10 rows x 41 columns]

# %% [markdown]
# ## Academies

# %%
df_academies.info()
display(df_academies.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397 entries, 1002 to 1779
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Academies  397 non-null    object
# dtypes: object(1)
# memory usage: 6.2+ KB
#                    Academies
# SP ID
# 1002          French Academy
# 1007   Acadmie des sciences
# 1009   Acadmie des sciences
# 1018          French Academy
# 1019           Royal Society
# 1019   Acadmie des sciences
# 1019          French Academy
# 1019          Berlin Academy
# 1019   St Petersburg Academy
# 1019   Royal Swedish Academy

# %%
category_prob_barh(df=df_academies, column="Academies")
# Out:
# c:\programdata\anaconda3\envs\petersont\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 142 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\programdata\anaconda3\envs\petersont\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 142 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
category_count_barh(df=df_academies, column="Academies", top_n=10)

# %% [markdown]
# ## Aristocracy title

# %%
df_aristo_title.info()
display(df_aristo_title.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 247 entries, 1017 to 1781
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Aristo title  247 non-null    object
# dtypes: object(1)
# memory usage: 3.9+ KB
#       Aristo title
# SP ID
# 1017           duc
# 1026         comte
# 1029      marquise
# 1030         comte
# 1030       marquis
# 1077       marquis
# 1090         comte
# 1090        prince
# 1101     chevalier
# 1119         baron

# %%
category_prob_barh(df=df_aristo_title, column="Aristo title")

# %%
category_count_barh(df=df_aristo_title, column="Aristo title", top_n=10)

# %% [markdown]
# ## Ego networks combined

# %%
df_egonetworkscombined.info()
display(df_egonetworkscombined.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1347 entries, 1000 to 1781
# Data columns (total 1 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EgoNetworksCombined  1347 non-null   object
# dtypes: object(1)
# memory usage: 21.0+ KB
#       EgoNetworksCombined
# SP ID
# 1000              Arnould
# 1001             Voltaire
# 1001              Arnould
# 1002             Voltaire
# 1002             Rousseau
# 1002              Arnould
# 1003             Voltaire
# 1003              Arnould
# 1004             Voltaire
# 1004           D'Alembert

# %%
category_prob_barh(df=df_egonetworkscombined, column="EgoNetworksCombined")

# %%
category_count_barh(df=df_egonetworkscombined, column="EgoNetworksCombined", top_n=10)

# %% [markdown]
# ## Knowledge network

# %%
df_knowledge_network.info()
display(df_knowledge_network.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 529 entries, 1000 to 1781
# Data columns (total 1 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Knowledge Network  529 non-null    object
# dtypes: object(1)
# memory usage: 8.3+ KB
#            Knowledge Network
# SP ID
# 1000        Letters_Literary
# 1001        Letters_Literary
# 1002        Letters_Literary
# 1003       Political Economy
# 1004   Letters_Philosophical
# 1004        Letters_Literary
# 1005        Letters_Literary
# 1009   Sciences_Mathematical
# 1014        Letters_Literary
# 1014               Collector

# %%
category_prob_barh(df=df_knowledge_network, column="Knowledge Network")

# %%
category_count_barh(df=df_knowledge_network, column="Knowledge Network", top_n=10)

# %% [markdown]
# ## Military rank

# %%
df_military_rank.info()
display(df_military_rank.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 1002 to 1771
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Military rank  40 non-null     object
# dtypes: object(1)
# memory usage: 640.0+ bytes
#               Military rank
# SP ID
# 1002                officer
# 1030   high-ranking_general
# 1039     lieutenant-colonel
# 1039      chef de bataillon
# 1039              capitaine
# 1163                officer
# 1185       marchal de camp
# 1189              marchale
# 1202     marchal de France
# 1222   high-ranking_general

# %%
category_prob_barh(df=df_military_rank, column="Military rank")
# Out:
# c:\programdata\anaconda3\envs\petersont\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 142 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\programdata\anaconda3\envs\petersont\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 142 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
category_count_barh(df=df_military_rank, column="Military rank", top_n=10)

# %% [markdown]
# ## Nationality

# %%
df_nationality.info()
display(df_nationality.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 776 entries, 1000 to 1781
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nationality  776 non-null    object
# dtypes: object(1)
# memory usage: 12.1+ KB
#       Nationality
# SP ID
# 1000       French
# 1001       French
# 1002       French
# 1003       French
# 1004        Swiss
# 1005       French
# 1006       German
# 1007       French
# 1008       French
# 1009       German

# %%
category_prob_barh(df=df_nationality, column="Nationality")

# %%
category_count_barh(df=df_nationality, column="Nationality", top_n=10)

# %% [markdown]
# ## Occupation

# %%
df_occupation.info()
display(df_occupation.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 888 entries, 1000 to 1781
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Occupation  888 non-null    object
# dtypes: object(1)
# memory usage: 13.9+ KB
#                                               Occupation
# SP ID
# 1000                         playwright,government agent
# 1001                              poet,author,playwright
# 1002   army officer,diplomat,soldier,academy member,a...
# 1003                            journalist,revolutionary
# 1004                                  author,philosopher
# 1005                                              author
# 1006                                            composer
# 1007                                           statesman
# 1008                                          aristocrat
# 1010                                    wife of a banker

# %%
category_prob_barh(df=df_occupation, column="Occupation")

# %%
category_count_barh(df=df_occupation, column="Occupation", top_n=10)
# Out:
# c:\programdata\anaconda3\envs\petersont\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 142 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\programdata\anaconda3\envs\petersont\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 142 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## Political rank

# %%
df_political_rank.info()
display(df_political_rank.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63 entries, 1002 to 1778
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Political rank  63 non-null     object
# dtypes: object(1)
# memory usage: 1008.0+ bytes
#                 Political rank
# SP ID
# 1002                  diplomat
# 1007                  minister
# 1022                  diplomat
# 1031                  minister
# 1035                    dput
# 1038        officier municipal
# 1048              consul-maire
# 1067                 capitaine
# 1067   commandant de bataillon
# 1067        lieutenant-colonel

# %%
category_prob_barh(df=df_political_rank, column="Political rank")
# Out:
# c:\programdata\anaconda3\envs\petersont\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 142 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\programdata\anaconda3\envs\petersont\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 142 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
category_count_barh(df=df_political_rank, column="Political rank", top_n=10)

# %% [markdown]
# ## Professional network

# %%
df_professional_network.info()
display(df_professional_network.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 347 entries, 1000 to 1777
# Data columns (total 1 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Professional Network  347 non-null    object
# dtypes: object(1)
# memory usage: 5.4+ KB
#       Professional Network
# SP ID
# 1000              Cultural
# 1001                Artist
# 1001              Cultural
# 1003              Cultural
# 1003                 Legal
# 1006                Artist
# 1009             Education
# 1014               Artisan
# 1014            Publishing
# 1018              Cultural

# %%
category_prob_barh(df=df_professional_network, column="Professional Network")

# %%
category_count_barh(df=df_professional_network, column="Professional Network", top_n=10)

# %% [markdown]
# ## Salons

# %%
df_salons.info()
display(df_salons.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1002 entries, 1000 to 1781
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Salons  1002 non-null   object
# dtypes: object(1)
# memory usage: 15.7+ KB
#           Salons
# SP ID
# 1000     Arnould
# 1001     Arnould
# 1002     Arnould
# 1003     Arnould
# 1004     Arnould
# 1004      Epinay
# 1004    Quinault
# 1004       Dupin
# 1004   Boufflers
# 1004      Necker

# %%
category_prob_barh(df=df_salons, column="Salons")

# %%
category_count_barh(df=df_salons, column="Salons", top_n=10)

# %% [markdown]
# ## Social network

# %%
df_social_network.info()
display(df_social_network.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1285 entries, 1000 to 1781
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Social Network  1285 non-null   object
# dtypes: object(1)
# memory usage: 20.1+ KB
#       Social Network
# SP ID
# 1000      Government
# 1000           Elite
# 1000           Court
# 1001        Military
# 1001      Aristoracy
# 1001           Elite
# 1002        Military
# 1002      Government
# 1002      Aristoracy
# 1002           Elite

# %%
category_prob_barh(df=df_social_network, column="Social Network")

# %%
category_count_barh(df=df_social_network, column="Social Network", top_n=10)

# %% [markdown]
# ## Source

# %%
df_source.info()
display(df_source.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 902 entries, 1000 to 1781
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Source  902 non-null    object
# dtypes: object(1)
# memory usage: 14.1+ KB
#        Source
# SP ID
# 1000       EE
# 1001       EE
# 1002       EE
# 1003       EE
# 1003   CNRS-D
# 1004       EE
# 1004   CNRS-D
# 1004   Kafker
# 1005       EE
# 1006       EE

# %%
category_prob_barh(df=df_source, column="Source")

# %%
category_count_barh(df=df_source, column="Source", top_n=10)
